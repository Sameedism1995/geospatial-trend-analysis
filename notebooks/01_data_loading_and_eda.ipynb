# %% [markdown]
# # Data Loading and EDA\n\nStarter notebook for loading a sample coastal water quality dataset and running quick exploratory analysis.

# %%
import pandas as pd\nimport matplotlib.pyplot as plt\nimport seaborn as sns\n\nsns.set_theme(style=\"whitegrid\")

# %%
# Load sample CSV\ndf = pd.read_csv(\"../data/sample_water_quality.csv\")\ndf.head()

# %%
# Basic descriptive stats\ndf.describe()

# %%
# Basic dataframe info\ndf.info()

# %%
# Simple distributions\nnumeric_cols = [\"salinity\", \"temperature\", \"turbidity\", \"vessel_count\"]\nfig, axes = plt.subplots(2, 2, figsize=(12, 8))\n\nfor ax, col in zip(axes.flat, numeric_cols):\n    sns.histplot(df[col], kde=True, ax=ax)\n    ax.set_title(f\"Distribution of {col}\")\n\nplt.tight_layout()\nplt.show()
